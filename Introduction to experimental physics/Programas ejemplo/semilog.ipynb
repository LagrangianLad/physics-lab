# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [0.4, 0.44, 0.5, 0.51, 0.53, 0.54, 0.56, 0.59, 0.60, 0.62]

# %%
y = [0.02, 0.09, 0.41,0.51,0.65,0.9,1.3,2.3,2.8,4.1]

# %%
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x, y,'o')

# %%
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x, y,'o')
