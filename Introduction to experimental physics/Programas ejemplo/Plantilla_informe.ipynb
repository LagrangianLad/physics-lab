# %% [markdown]
# # TÍTULO DE LA PRÁCTICA: MEDIDA DE X
#
# **Autor responsable**: Alumna 1
#
# **Autores**: Alumna 1 y Alumno 2
#
# **Grupo**: G1
#
# **Fecha del informe**: 02/02/2026

# %% [markdown]
# ## INFORMACIÓN GENERAL DEL LABORATORIO
#
# **Fecha de realización de la práctica**: 29/01/26
#
# **Tempertatura**: 25ºC
#
# **Presión**: 1035 HPa
#
# **Humedad relativa**: 50%

# %% [markdown]
# ## CARGA DE LIBRERÍAS DE PYTHON

# %%
import numpy as np
import math
import matplotlib.pyplot as plt  
from __future__ import print_function
from scipy import stats
from scipy.optimize import curve_fit 
from scipy.stats import t

# %% [markdown]
# ## 1. INTRODUCCIÓN Y OBJETIVOS

# %% [markdown]
# Breve resumen de en qué consiste la práctica y qué se pretende.
#
# Voy a medir...
# - No se qué.
# - No sé cuántos.
# - ...

# %% [markdown]
# ## 2. PROCEDIMIENTO Y MONTAJE EXPERIMENTAL

# %% [markdown]
# Hago un breve resumen de lo que se ha hecho en la práctica e indico las ecuaciones más relevantes (principalmente, las que vaya a utilizar ara el análisis), a poder ser en $\LaTeX$:
# $$
# \rho = \frac{m}{V}
# $$
# Y lo que me haga falta para que se entienda el informe:
# $$
# \left( \frac{u_{\rho}}{\rho} \right)^2 = \left( \frac{u_m}{m} \right)^2 + \left( \frac{u_V}{V} \right)^2
# $$
# ...

# %% [markdown]
# Es posible también incluir imágenes (que han de cargarse en la lista de ficheros de Jupyter Notebook y debe estar presente en la carpeta donde bajes el fichero HTML también). Haz doble click en la imagen para ver el código:

# %% [markdown]
# <img src="DiametroEuroPieDeRey002mm.png" width="500">
#
# *Figura 1*: Un pie de rey con 1€

# %% [markdown]
# ### 2.1. Intrumentos utilizados

# %% [markdown]
# Breve descripción de los instrumentos de medida utilizados y la resolución de cada uno.

# %% [markdown]
# ## 3. RESULTADOS

# %% [markdown]
# Aquí recojo con claridad y orden todas las medidas realizadas.
#
# Cuando sea necesario, incluyo tablas en un formato adecuado:
#
# |$h$ (cm)|$t_1$ (s)|$t_2$ (s)|$t_3$ (s)|$t_4$ (s)|$t_5$ (s)|
# |---|---|---|---|---|---|
# |29.4|0.257|0.253|0.250| | |
# |44.9|0.313|0.311|0.311|0.315| |
# |68.7|0.385|0.383|0.378|0.380|0.380|
# |87.1|0.425|0.432|0.425|0.424|0.422|
# |113.6|0.505|0.508|0.502|0.497|0.499|
# |130.1|0.511|0.518|0.513|0.515|0.514|
# |150.7|0.550|0.552|0.549|0.549| |
# |173.5|0.625|0.628|0.616|0.639|0.635|
# |184.2|0.619|0.620|0.618|0.642|0.630|

# %% [markdown]
# Cuando sea necesario, incluyo figuras en un formato adecuado:

# %%
hs = [0.294, 0.449, 0.687, 0.871, 1.136, 1.301, 1.507, 1.735, 1.842]

# %%
tmedios = [0.25333333333333335, 0.3125, 0.38119999999999993, 0.42560000000000003, 0.5022, 0.5142, 0.55, 0.6285999999999999, 0.6257999999999999]

# %%
plt.plot(hs, tmedios, 'o', label='Medidas')
plt.xlabel("h (m)")
plt.ylabel("t (s)")
plt.legend()
plt.show()

# %% [markdown]
# Aquí sacaré también toda la información relevante que se pueda extraer de las medidas: valores medios, incertidumbres, ajustes por mínimos cuadrados y parámetros inferidos...

# %% [markdown]
# ### 3.1. Resumen de los resultados

# %% [markdown]
# Para recapitular, la densidad del aluminio medida ha sido de:
#
# $$
# \rho = 2.618 \pm 0.037 \, \text{g/cm}^3
# $$
#
# ...

# %% [markdown]
# ## 4. DISCUSIÓN Y CONCLUSIONES

# %% [markdown]
# Comparación de los resultados con los valores de los parámetros en la bibliografía, error absoluto y relativo, incidencias, comentarios, posibles formas de mejorar los resultados, valoración de la práctica…

# %% [markdown]
# # BILBIOGRAFÍA

# %% [markdown]
# - *Aluminio*, Wikipedia, la enciclopedia libre. [Disponible online](https://es.wikipedia.org/wiki/Aluminio)
# - *Markdown for Jupyter notebooks cheatsheet*, IBM Documentation. [Disponible online](https://www.ibm.com/docs/en/watson-studio-local/1.2.3?topic=notebooks-markdown-jupyter-cheatsheet)

# %% [markdown]
# # ANEXOS

# %% [markdown]
# Cálculos largos y pesados, mejor los hago aquí, y en las secciones de arriba dejo sólo los resultados relevantes.
#
# Aquí vendrían cálculos como los del Notebook 'pie_de_rey_incertidumbre_ejemplo.ipynb', bien ordenados y estructurados, para que el profesor lo pueda corregir.
#
# En el texto principal, haré referencia a que tal cálculo se ha realizado en los anexos.

# %% [markdown]
# ## Anexo 1. Cálculo de los valores medios e incertidumbres de las dimensiones de la pieza 1

# %% [markdown]
# ...
